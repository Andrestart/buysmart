# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
from selenium.webdriver.support.ui import Select
from webdriver_manager.chrome import ChromeDriverManager
import time
import requests
from bs4 import BeautifulSoup
import os
from datetime import datetime

# %%
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)
opciones.headless=False 
opciones.add_argument('--start-maximized')
# opciones.add_argument('--incognito')

# %%
e = ['ajo','albaricoque']

# %%
driver = "../driver/chromedriver.exe"
driver = webdriver.Chrome(driver, options=opciones)
supermarket = "alcampo"
prices = []
prod = []
sup = []
links = []
names = []
frame = {}
for f in e:
    time.sleep(1)
    url = f"https://www.alcampo.es/compra-online/search/?department=&text={f}"
    time.sleep(1.5)
    driver.get(url)
    time.sleep(1)
    try:
        driver.find_element_by_css_selector('body > div.cc_overlay_lock > div > div > div:nth-child(4) > button.cc_b_ok.auxOKButton.cookie-button').click()
    except:
        pass
    time.sleep(1)
    try:
        driver.find_element_by_css_selector('#navContainer > div.ui-widget-overlay.first-time-overlay').click()
    except:
        pass
    time.sleep(.5)
    for i in range(1,15):
        try:
            prices.append(driver.find_element_by_css_selector(f'#content > div.span-20.last.slideGridDiv3 > div:nth-child(5) > div > div:nth-child({i}) > div > div.cart.clearfix > div.precioFila > div.priceContainer > span.price.long-price.precio15 > span').text.split("€")[0].split("(")[1].strip())
            names.append(driver.find_element_by_css_selector(f'#content > div.span-20.last.slideGridDiv3 > div:nth-child(5) > div > div:nth-child({i}) > div > div:nth-child(1) > a:nth-child(3) > div > div > span').text)
            prod.append(f)
            sup.append(supermarket)
            links.append(url)
        except:
            pass
frame['prices'] = prices
frame['product'] = prod
frame['supermarket'] = sup
frame['links'] = links
frame['names'] = names
scrap = pd.DataFrame(frame)
scrap.dropna(how='any',inplace=True)
if not os.path.exists(f"../mydata/scraps_{supermarket}"):
    os.makedirs(f"../mydata/scraps_{supermarket}")
    now = str(datetime.now())[:19].replace(":","_")
    scrap.to_csv(f'../mydata/scraps_{supermarket}/{now}.csv')
# Out:
# /tmp/ipykernel_460/3574564452.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(driver, options=opciones)
# /tmp/ipykernel_460/3574564452.py:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector('body > div.cc_overlay_lock > div > div > div:nth-child(4) > button.cc_b_ok.auxOKButton.cookie-button').click()
# /tmp/ipykernel_460/3574564452.py:22: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector('#navContainer > div.ui-widget-overlay.first-time-overlay').click()
# /tmp/ipykernel_460/3574564452.py:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   prices.append(driver.find_element_by_css_selector(f'#content > div.span-20.last.slideGridDiv3 > div:nth-child(5) > div > div:nth-child({i}) > div > div.cart.clearfix > div.precioFila > div.priceContainer > span.price.long-price.precio15 > span').text.split("€")[0].split("(")[1].strip())
# /tmp/ipykernel_460/3574564452.py:29: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   names.append(driver.find_element_by_css_selector(f'#content > div.span-20.last.slideGridDiv3 > div:nth-child(5) > div > div:nth-child({i}) > div > div:nth-child(1) > a:nth-child(3) > div > div > span').text)

# %%
scrap
# Out:
#   prices product supermarket  \
# 0   8,90     ajo     alcampo
# 1   6,98     ajo     alcampo
# 2   2,99     ajo     alcampo
# 3   6,58     ajo     alcampo
# 4   4,48     ajo     alcampo
# 5   6,60     ajo     alcampo
# 6   7,83     ajo     alcampo
# 7   2,05     ajo     alcampo
# 8   1,52     ajo     alcampo
# 9   6,85     ajo     alcampo
#
#                                                links  \
# 0  https://www.alcampo.es/compra-online/search/?d...
# 1  https://www.alcampo.es/compra-online/search/?d...
# 2  https://www.alcampo.es/compra-online/search/?d...
# 3  https://www.alcampo.es/compra-online/search/?d...
# 4  https://www.alcampo.es/compra-online/search/?d...
# 5  https://www.alcampo.es/compra-online/search/?d...
# 6  https://www.alcampo.es/compra-online/search/?d...
# 7  https://www.alcampo.es/compra-online/search/?d...
# 8  https://www.alcampo.es/compra-online/search/?d...
# 9  https://www.alcampo.es/compra-online/search/?d...
#
#                                                names
# 0                    Ajo morado Peregrin GOLD 100 g.
# 1                              Ajo morado 500 gramos
# 2                    Combinado de ajo y cebolla 1 kg
# 3                                        Ajos 500 g.
# 4                                        Ajos 500 g.
# 5                                         Ajos 250 g
# 6       Maiz superdulce ultracongelado FINDUS 300 g.
# 7  Maíz dulce en grano, ultracongelado PRODUCTO A...
# 8   Cebolla cortada en dados PRODUCTO ALCAMPO 400 g.
# 9  Picadillo de variantes en vinagre RIOVERDE 200 g.
